# %% [markdown]
# <a href="https://colab.research.google.com/github/navyagithub123/Navya5F5/blob/main/Linear%20Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
x = np.array([ [1] , [2] , [3] , [4] , [5] ])
y = np.array([ 1 , 2 , 2.5 , 4 , 5])

# %%
model = LinearRegression()
model.fit(x,y)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x)

# %%
plt.scatter(x, y, color='blue')
plt.plot(x, y_pred, color='purple')
plt.title("Linear Regression")
plt.xlabel("x")
plt.ylabel("y")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
print("Intercept (β0):", model.intercept_)
print("Coefficient (β1):", model.coef_)
# Out:
# Intercept (β0): -0.10000000000000009
# Coefficient (β1): [1.]

# %%
X = np.random.rand(100, 1) * 100
Y = 2 * X + np.random.randn(100, 1) * 10

# %%
plt.scatter(X, Y, color='orange')
plt.title("Generated Dataset of 100 Numbers")
plt.xlabel("X")
plt.ylabel("Y")
plt.show()

# %%
model = LinearRegression()
model.fit(X, Y)
# Out:
# LinearRegression()

# %%
Y_pred = model.predict(X)

# %%
plt.scatter(X, Y, color='orange')
plt.plot(X, Y_pred, color='purple')
plt.title("Linear Regression")
plt.xlabel("X")
plt.ylabel("Y")
plt.show()

# %%
print("Intercept (β0):", model.intercept_)
print("Coefficient (β1):", model.coef_)
# Out:
# Intercept (β0): [1.94397253]
# Coefficient (β1): [[1.99364386]]
